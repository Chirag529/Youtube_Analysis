# %% [markdown]
# # Comments from a Particular With Video_ID

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCsc7GEiN__DpQfEORqa0OnU9LOGUxkQiY"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="qC0l7kLpmi8",
    maxResults= 1000
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Nhi me esaa Kyu ke rha hu ke caseeto ka fix.h pehle se hi jitna mega ramp me 🤔😐
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=9m28s">9:28</a> Jab bache me muuh se lollipop chura li ho😂
# Nice competition on this race 👍
# Take care vai dhiyan rakha karo apni ❤❤<br>Love from Bangladesh
# jan buj kr niche gira di Bc,😂😂😂
# Casetoo is suffering the chances of survival is very low😢 may your soul rip
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=20m20s">20:20</a> waah kya रोता है😂😂😂😂😂😂
# Bhai choty se chot k leye itna raona 😑
# Casetoo videos titles are unmatchable 😂😂😂😂
# play valorant
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=20m20s">20:20</a> that &quot;aaaaaaaaaa&quot; too good🤣🤣
# bhai  light  ka  bill  jama  kar  diya  karo  hamesha  game  pley  me  light  chali  jati  he                ❤ big  fen  bro  ❤
# Sabse bda nal bazz tum ho😂😂🎉
# <a href="http://www.youtube.com/results?search_query=%23papaplayer">#PAPAPLAYER</a> CASETOO ❤🎉🎉
# Nunu pakadke 😂
# Casetoo Bhai itne ad Mt do paise nahi ye SB khareedne ke + fun ruk jata hai😭😭
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=1m36s">1:36</a> 🤣🤣🤣🤣 mujhe hurt ho raha hai bigboss😂😂😂
# Casetoo&#39;s gameplay ❌Casetoo&#39;s rage✔️
# My 1%  volume is enough to watch casetoo gta5 video 😂😂😂
# I don&#39;t want any song app i see c2 and download new songs 😂😂
# That&#39;s called wounded lion?
# Chop bite caseetoo😅😅😅
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=5m06s">5:06</a> suraj c2 moment 😂
# <a href="https://youtu.be/YIXZ54i6uT0">https://youtu.be/YIXZ54i6uT0</a>
# How can i play gta 5 with you @The Casetoo
# BGMI ma update aa gya ha vote kar do jisko patta ha ❤❤
# Casetoo bhaiya Goku wala update a gaya BGMi ai😊
# maja hi aagya 🔥
# Bgmi new update is out
# Hi
# 👍👍👍👍
# What happened to his finger?
# Guyzz casetoo is fake fan of gurujii becauss he not even followed gurujii on insta
# Vote For Impossible Heist 😢
# When you understand the lyrics of Castoo&#39;s song in this video 😢👍
# Casetoo&#39;s love for Guruji and Suraj is unmatchable. 😂
# Bsd  ghodu k roj yahi upload karega ramp race mystery box or truck sumo kar
# New nickname <br> C2 The Bollywood remixer
# Every players is temporary but,. &#39;SURAJ&#39; IS PERMANENT IN EVERY GAME😄
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=9m35s">9:35</a> 🤣🤣🤣🤣🤣🤣
# Vote c2 for playing hellseed👍
# #####<a href="http://www.youtube.com/results?search_query=%23papa">#Papa</a> player😍👿👿👿😈😈😈
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t
href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=18m55s">18:55</a> | 🏁FINISH <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=19m35s">19:35</a>
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=18m15s">18:15</a> booba boba boba boba o na we go ahead we speen one time speen one time like this and sadanly he said o na o na 🤣🤣🤣
# <a href="https://www.youtube.com/watch?v=qC0l7kLpmi8&amp;t=0m20s">0:20</a> Intro 😂😂😂
# Casetoo vai tum ek rosting channel open karo
# C2 ke hat me ladki ne kata 🤣🤣
# Per bhaiya mai tho video dekh raha tha lekin meri gardan kaise tedhi ho gayi🤪
# Car vs car
# Op
# Papa player
# Vote for Qna video
# Op
# We want suraj back😢😢😢
# <a href="http://www.youtube.com/results?search_query=%23papaplayer">#papaplayer</a>
# @THE CASETOO How to play Gta 5 with your small finger?

# %%
# Save the comments to a data Frame for later use

import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCsc7GEiN__DpQfEORqa0OnU9LOGUxkQiY"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="qC0l7kLpmi8",
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# df.to_csv('comments.csv', index=False)
# Out:
#                        author          published_at            updated_at  \
# 0                  Arun Singh  2023-08-13T07:08:13Z  2023-08-13T07:08:13Z
# 1            Arnav Sagar Ishu  2023-08-11T13:51:18Z  2023-08-11T13:51:18Z
# 2             Muslim brothers  2023-08-11T13:13:30Z  2023-08-11T13:13:30Z
# 3                 Sultan Khan  2023-08-10T19:38:29Z  2023-08-10T19:38:29Z
# 4               Sourbh Sharma  2023-08-10T12:23:59Z  2023-08-10T12:23:59Z
# 5       S-Series Bhakti Sagar  2023-08-10T11:02:38Z  2023-08-10T11:02:38Z
# 6                      Dr KBC  2023-08-10T11:01:57Z  2023-08-10T11:01:57Z
# 7  shivam sharma278 explosion  2023-08-10T10:34:16Z  2023-08-10T10:34:16Z
# 8             Alamdar Hussain  2023-08-10T09:36:26Z  2023-08-10T09:36:26Z
# 9                  PIHU YT FF  2023-08-10T09:08:09Z  2023-08-10T09:08:09Z
#
#    like_count                                               text
# 0           0                  Ya. Mega. Tati. Kitna. Bar. Ghira
# 1           1  Casetoo Bhai Damage Finger Hone Baat Bhi Winne...
# 2           0    Saleeee 100 bar tune bahana laga diya dard ka 😂
# 3           0                               Mega ramp is backk 🎉
# 4           0              Pichwade ma ungali daal di thi isliye
# 5           0  <a href="https://www.youtube.com/watch?v=qC0l7...
# 6           0  Casetoo<br>Highly Pro in Mega ramp and troll r...
# 7           0                                  majak se haat k👌😂
# 8           0  Yar casetoo is one of the best YouTuber ❤❤best...
# 9           0                      Fish and feed grow game khelo
